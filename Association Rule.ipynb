# %%
import sys
from itertools import chain, combinations, islice
from collections import defaultdict
from optparse import OptionParser
from openpyxl import load_workbook
from operator import mul
from functools import reduce
import pandas as pd
import operator

# %%
df = pd.read_csv(r'Dataset\siswa.csv')
df
# Out:
#     No  no Induk               Nama jen kel       alamat  Agama   Tgl Lahir  \
# 0    1      2683        Ani Yuanita       P  Tegallayang  Islam   11/3/1993
# 1    2      2686    Burhan Fajar P.       L  Tegallayang  Islam  29/12/1993
# 2    3      2688     Heri Budiyanto       L  Tegallayang  Islam   2/15/1994
# 3    4      2700    Dimas Satrio W.       L  Tegallayang  Islam   4/20/1994
# 4    5      2701        Nur Hidayat       L  Tegallayang  Islam   6/12/1994
# 5    6      2702      Vilda Lestari       P  Tegallayang  Islam   6/25/1994
# 6    7      2703       Edi Suryanto       L  Tegallayang  Islam    7/6/1994
# 7    8      2705   Erna Dwi Puspita       P  Tegallayang  Islam   9/12/1994
# 8    9      2706         Nurfita FF       P      Daguran  Islam   4/10/1994
# 9   10      2707       Fahmi dwi N.       L  Tegallayang  Islam   5/10/1994
# 10  11      2709    Hamzah Pramudya       L  Tegallayang  Islam  11/15/1994
# 11  12      2710           Nurcahto       L  Tegallayang  Islam  11/19/1994
# 12  13      2711        Aminatun R.       P  Tegallayang  Islam  11/29/1994
# 13  14      2712       Tri Haryanto       L  Tegallayang  Islam  21/12/1994
# 14  15      2715  Irma Kautsaril Q.       P      Daguran  Islam   2/11/1995
# 15  16      2718        Risna Dania       P  Tegallayang  Islam   3/22/1995
# 16  17      2720      Ageng Priyono       L  Tegallayang  Islam   4/30/1995
# 17  18      2722       Reny Surya P       P  Tegallayang  Islam   6/14/1995
# 18  19      2723   Layly Aslinda S.       P  Tegallayang  Islam   6/15/1995
# 19  20      2724     David Setiarso       L  Tegallayang  Islam   6/29/1995
# 20  21      2726           Agne Cia       P  Tegallayang  Islam   15/8/1995
# 21  22      2727       Hari Anggoro       L  Tegallayang  Islam  10/10/1995
# 22  23      2728        Anas Bayu P       L  Tegallayang  Islam  22/10/1995
# 23  24      2627    Danar Apriyanto       L  Tegallayang  Islam    4/6/1993
# 24  25      2704   Agus Dwi Saputra       L  Tegallayang  Islam    9/8/1994
# 25  26      2721      Wahyu Hidayat       L  Tegallayang  Islam   25/5/1995
# 26  27      2725     Slamet Riyanto       L  Tegallayang  Islam   6/26/1995
# 27  28      2729    Ahmad Alfian Y.       L  Tegallayang  Islam   9/14/1995
# 28  29      2730   Andini Setyowati       P  Tegallayang  Islam   3/10/1995
#
#    Tmpt Lahir             Nama_Wali Pekerjaan Wali  Pend  alamat wali  \
# 0      Bantul               Sukarjo         Petani    SD  Tegallayang
# 1      Bantul          Hadi Wardoyo         Petani   SMA  Tegallayang
# 2      Bantul                 Ribut         Petani   NaN  Tegallayang
# 3      Bantul   FX Slamet Sudarsono            PNS    PT  Tegallayang
# 4    Kuningan                  Ofan     Wiraswasta  SLTP  Tegallayang
# 5      Bantul              Rochmadi         Petani  SLTP  Tegallayang
# 6      Bantul               Sukiman         Petani    SD  Tegallayang
# 7      Bantul               Sumarjo     Wiraswasta    SD  Tegallayang
# 8      Bantul                Giyana     Wiraswasta    SD  Tegallayang
# 9      Bantul             Syamsudin         Petani    SD  Tegallayang
# 10     Bantul         Slamet Riyadi     Wiraswasta  SLTA  Tegallayang
# 11     Bantul              Sarjiman         Petani    SD  Tegallayang
# 12     Bantul            Supriyanto            PNS  SLTA  Tegallayang
# 13     Bantul               Sugiman     Wiraswasta    SD  Tegallayang
# 14       Same  Drs. Mursid Purwanto            PNS    S1      Daguran
# 15     Bantul                Kasidi         Petani    SD  Tegallayang
# 16     Bantul              Suwarnun         Petani  SLTP  Tegallayang
# 17     Bantul             Markiyono         Petani    SD  Tegallayang
# 18      Blora                Rukidi           ABRI  SLTP  Tegallayang
# 19     Bantul                Jualdi         Petani    SD  Tegallayang
# 20     Bantul          Wahid Wahono     Wiraswasta  SLTP  Tegallayang
# 21     Bantul                Kamidi     Wiraswasta    SD  Tegallayang
# 22     Bantul                Ratijo         Petani  SLTA  Tegallayang
# 23     Bantul              Suratijo         Petani  SLTP  Tegallayang
# 24     Bantul                Karnen         Petani    SD  Tegallayang
# 25     Bantul           Subardiyono         Petani    SD  Tegallayang
# 26     Bantul                Paiman         Petani    SD  Tegallayang
# 27     Bantul         Yitno Pranoto     Wiraswasta   SPG  Tegallayang
# 28     Bantul                Paniyo     Wiraswasta  SLTP  Tegallayang
#
#     Thn msk  usia msk   lulus    UAS predikat pend sebelumSD
# 0      2000         7    2007   17,9    Cukup             TK
# 1      2000         7    2007   16,9    Cukup             TK
# 2      2000         6    2007  20,15    Cukup             TK
# 3      2001         7    2007  18,35    Cukup             TK
# 4      2001         7    2007   26,1     Baik             TK
# 5      2001         7    2007   13,6   Kurang             TK
# 6      2001         7    2007  22,65     Baik             TK
# 7      2001         7    2007  18,05    Cukup             TK
# 8      2001         7    2007  16,15    Cukup             TK
# 9      2001         7    2007   26,9     Baik             TK
# 10     2001         7    2007  20,95    Cukup             TK
# 11     2001         7    2007  25,25     Baik             TK
# 12     2001         7    2007  25,45     Baik             TK
# 13     2001         7    2007  28,85     Baik             TK
# 14     2001         6    2007   25,4     Baik             TK
# 15     2001         6    2007   25,1     Baik             TK
# 16     2001         6    2007   24,2     Baik             TK
# 17     2001         6    2007   26,6     Baik             TK
# 18     2001         6    2007  27,15     Baik             TK
# 19     2001         6    2007   26,5     Baik             TK
# 20     2001         6    2007   24,6     Baik             TK
# 21     2001         6    2007   20,5    Cukup             TK
# 22     2001         6    2007  18,45    Cukup             TK
# 23     2000         7    2008   18,3    Cukup             TK
# 24     2001         7    2008  16,45    Cukup             TK
# 25     2001         6    2008   23,2     Baik            NaN
# 26     2001         6    2008  18,75    Cukup             TK
# 27     2002         7    2008   23,1     Baik             TK
# 28     2002         7    2008  21,85     Baik             TK

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
# 11     Bantul            Supriyanto            PNS  SLTA  Tegallayang
# 12     Bantul               Sugiman     Wiraswasta    SD  Tegallayang
# 13       Same  Drs. Mursid Purwanto            PNS    S1      Daguran
# 14     Bantul                Kasidi         Petani    SD  Tegallayang
# 15     Bantul              Suwarnun         Petani  SLTP  Tegallayang
# 16     Bantul             Markiyono         Petani    SD  Tegallayang
# 17      Blora                Rukidi           ABRI  SLTP  Tegallayang
# 18     Bantul                Jualdi         Petani    SD  Tegallayang
# 19     Bantul          Wahid Wahono     Wiraswasta  SLTP  Tegallayang
# 20     Bantul                Kamidi     Wiraswasta    SD  Tegallayang
# 21     Bantul                Ratijo         Petani  SLTA  Tegallayang
# 22     Bantul              Suratijo         Petani  SLTP  Tegallayang
# 23     Bantul                Karnen         Petani    SD  Tegallayang
# 24     Bantul                Paiman         Petani    SD  Tegallayang
# 25     Bantul         Yitno Pranoto     Wiraswasta   SPG  Tegallayang
# 26     Bantul                Paniyo     Wiraswasta  SLTP  Tegallayang
#
#     thn_masuk  usia_msk  lulus    uas predikat pend_sebelum_sd
# 0        2000         7   2007   17,9    Cukup              TK
# 1        2000         7   2007   16,9    Cukup              TK
# 2        2001         7   2007  18,35    Cukup              TK
# 3        2001         7   2007   26,1     Baik              TK
# 4        2001         7   2007   13,6   Kurang              TK
# 5        2001         7   2007  22,65     Baik              TK
# 6        2001         7   2007  18,05    Cukup              TK
# 7        2001         7   2007  16,15    Cukup              TK
# 8        2001         7   2007   26,9     Baik              TK
# 9        2001         7   2007  20,95    Cukup              TK
# 10       2001         7   2007  25,25     Baik              TK
# 11       2001         7   2007  25,45     Baik              TK
# 12       2001         7   2007  28,85     Baik              TK
# 13       2001         6   2007   25,4     Baik              TK
# 14       2001         6   2007   25,1     Baik              TK
# 15       2001         6   2007   24,2     Baik              TK
# 16       2001         6   2007   26,6     Baik              TK
# 17       2001         6   2007  27,15     Baik              TK
# 18       2001         6   2007   26,5     Baik              TK
# 19       2001         6   2007   24,6     Baik              TK
# 20       2001         6   2007   20,5    Cukup              TK
# 21       2001         6   2007  18,45    Cukup              TK
# 22       2000         7   2008   18,3    Cukup              TK
# 23       2001         7   2008  16,45    Cukup              TK
# 24       2001         6   2008  18,75    Cukup              TK
# 25       2002         7   2008   23,1     Baik              TK
# 26       2002         7   2008  21,85     Baik              TK

# %%
def subsets(arr):
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])

def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet
def joinSet(itemSet, length):
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])

def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList

def runApriori(data_iter, minSupport, minConfidence):
   
    itemSet, transactionList = getItemSetTransactionList(data_iter)

    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules

    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)

    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1

    def getSupport(item):
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in largeSet.items():
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in islice(largeSet.items(), 1, None):
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules


def printResults(items, rules):
    dSupport = {}
    for item, support in sorted(items, key=operator.itemgetter(1)):
        dSupport[item] = support
        print("item: %s , %.3f" % (str(item), support))

    for rule, confidence in sorted(rules, key=operator.itemgetter(1)):
        pre, post = rule
        tempRule=()
        tempRule+=pre
        tempRule+=post
        supportAimplikasiB = getSupportAimplikasiB(tempRule, dSupport)
        lift = supportAimplikasiB/(dSupport[pre]*dSupport[post])
        print("Rule: %s ==> %s : [confidence is %.3f, lift is %.3f]" % (str(pre), str(post), confidence, lift))

def getSupportAimplikasiB(A, B):
    rule = list(A)
    dict_support = B
    result = 0
    for index_dict_support in dict_support:
        list_index_dict_support = list(index_dict_support)
        check = []
        for data_index in list_index_dict_support:
            if data_index in rule and len(list_index_dict_support) >= len(rule):
                check.append(True)
            else:
                check.append(False)
        if(reduce(mul, check, 1)==True):
#             print(list_index_dict_support)
#             print(dict_support[index_dict_support])
            result = dict_support[index_dict_support]
    
    return result

def dataFromFile(fname):
        file_iter = open(fname, 'rU')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record

# %%
list_data, temp_data = [], []
for index, data in d.iterrows():
    temp_data.append(data['usia_msk'])
    temp_data.append(data['predikat'])        
    list_data.append(temp_data)
    temp_data = []
list_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bf8cf69f99c2> in <module>
#       1 list_data, temp_data = [], []
# ----> 2 for index, data in d.iterrows():
#       3     temp_data.append(data['usia_msk'])
#       4     temp_data.append(data['predikat'])
#       5     list_data.append(temp_data)
#
# NameError: name 'd' is not defined

# %%
minSupport = 0.1
minConfidence = 0.2

items, rules = runApriori(list_data, minSupport, minConfidence)
printResults(items, rules)
